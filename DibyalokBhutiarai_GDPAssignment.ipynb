# %%
import pandas as pd
import glob
path =r'C:\Dibyalok\1A'
all_files = glob.glob(path+'/*.csv')
df = pd.read_csv(all_files[0])
df.head()
df = pd.read_csv(all_files[0])
df = df[['Andhra Pradesh','Arunachal Pradesh','Assam','Bihar','Chhattisgarh','Goa','Gujarat','Haryana','Himachal Pradesh','Jammu & Kashmir','Jharkhand','Karnataka','Kerala','Madhya Pradesh','Maharashtra','Manipur','Meghalaya','Mizoram','Nagaland','Odisha','Punjab','Rajasthan','Sikkim','Tamil Nadu','Telangana','Tripura','Uttar Pradesh','Uttarakhand','West Bengal1']]
df.T
df.head(15)
df = pd.read_csv(all_files[0])
df = df[['Duration','Andhra Pradesh']]
df=df[6:]
df.head(15)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.scatter(x='Duration',y='Andhra Pradesh',data = df)
plt.show()

# %%
import pandas as pd
import glob
path =r'C:\Dibyalok\1A'
all_files = glob.glob(path+'/*.csv')

li =[]
for file in all_files:
    df = pd.read_csv(file)
##df.head()
##df = pd.read_csv(all_files[0])
##df = df[['Andhra Pradesh','Arunachal Pradesh','Assam','Bihar','Chhattisgarh','Goa','Gujarat','Haryana','Himachal Pradesh','Jammu & Kashmir','Jharkhand','Karnataka','Kerala','Madhya Pradesh','Maharashtra','Manipur','Meghalaya','Mizoram','Nagaland','Odisha','Punjab','Rajasthan','Sikkim','Tamil Nadu','Telangana','Tripura','Uttar Pradesh','Uttarakhand','West Bengal1']]
##df.T
##df.head(15)
##df = pd.read_csv(all_files[0])
    df = df[['Duration','Andhra Pradesh']]
    df=df[6:]
    df.head(15)
    li.append(df)

# %%
li
# Out:
# [   Duration  Andhra Pradesh
#  6   2012-13            8.43
#  7   2013-14           12.85
#  8   2014-15           13.40
#  9   2015-16           15.85
#  10  2016-17           14.65]

# %%
import pandas as pd
import glob
path =r'C:\Dibyalok\1A'
all_files = glob.glob(path+'/*.csv')

li =[]
for file in all_files:
    df = pd.read_csv(file)
##df.head()
##df = pd.read_csv(all_files[0])
    df = df[['Duration','Andhra Pradesh','Arunachal Pradesh','Assam','Bihar','Chhattisgarh','Goa','Gujarat','Haryana','Himachal Pradesh','Jammu & Kashmir','Jharkhand','Karnataka','Kerala','Madhya Pradesh','Maharashtra','Manipur','Meghalaya','Mizoram','Nagaland','Odisha','Punjab','Rajasthan','Sikkim','Tamil Nadu','Telangana','Tripura','Uttar Pradesh','Uttarakhand','West Bengal1']]
##df.T
##df.head(15)
##df = pd.read_csv(all_files[0])
    ##df = df[['Duration','Andhra Pradesh']]
    df=df[6:]
    df.head(15)
    li.append(df)

# %%
li
# Out:
# [   Duration  Andhra Pradesh  Arunachal Pradesh  Assam  Bihar  Chhattisgarh  \
#  6   2012-13            8.43              13.41   9.56  14.25         12.30
#  7   2013-14           12.85              16.38  13.31  12.30         16.44
#  8   2014-15           13.40              14.79  11.45  17.92         13.69
#  9   2015-16           15.85              12.07  13.19  10.59         10.98
#  10  2016-17           14.65                NaN    NaN    NaN         11.26
#
#        Goa  Gujarat  Haryana  Himachal Pradesh  ...  Odisha  Punjab  Rajasthan  \
#  6  -10.02    17.69    16.63             13.89  ...   13.34   11.67      13.18
#  7   -5.77    11.47    15.45             14.42  ...   12.95   12.42      11.27
#  8   13.12    10.82     9.18             10.14  ...   10.37    9.95      11.37
#  9   10.75    11.09    10.91               NaN  ...    6.19     NaN        NaN
#  10    NaN      NaN    12.82               NaN  ...   10.85     NaN        NaN
#
# ...

# %%
##Code to Plot a graph for rows " % Growth over previous year" 
##for all the states (not union territories) whose data is available, 
##use as much data as possible for this exercise.

import pandas as pd
import glob
path =r'C:\Dibyalok\1A'
all_files = glob.glob(path+'/*.csv')

li =[]
for file in all_files:
    df = pd.read_csv(file)
    df = df[['Duration','Andhra Pradesh','Arunachal Pradesh','Assam','Bihar','Chhattisgarh','Goa','Gujarat','Haryana','Himachal Pradesh','Jammu & Kashmir','Jharkhand','Karnataka','Kerala','Madhya Pradesh','Maharashtra','Manipur','Meghalaya','Mizoram','Nagaland','Odisha','Punjab','Rajasthan','Sikkim','Tamil Nadu','Telangana','Tripura','Uttar Pradesh','Uttarakhand','All_India GDP']]
    df=df[6:]
    df.head(15)
    li.append(df)
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.scatter(x='Duration',y='Andhra Pradesh',data = df)
plt.ylabel('Year')
plt.xlabel('Andhra Pradesh')
plt.show()

plt.scatter(x='Duration',y='Arunachal Pradesh',data = df)
plt.ylabel('Year')
plt.xlabel('Arunachal Pradesh')
plt.show()

plt.scatter(x='Duration',y='Assam',data = df)
plt.ylabel('Year')
plt.xlabel('Assam')
plt.show()
plt.scatter(x='Duration',y='Bihar',data = df)
plt.ylabel('Year')
plt.xlabel('Bihar')
plt.show()

plt.scatter(x='Duration',y='Chhattisgarh',data = df)
plt.ylabel('Year)')
plt.xlabel('Chhattisgarh')
plt.show()

plt.scatter(x='Duration',y='Goa',data = df)
plt.ylabel('Year')
plt.xlabel('Goa')
plt.show()
plt.scatter(x='Duration',y='Gujarat',data = df)
plt.ylabel('Year')
plt.xlabel('Gujarat')
plt.show()

plt.scatter(x='Duration',y='Haryana',data = df)
plt.ylabel('Year)')
plt.xlabel('Haryana')
plt.show()

plt.scatter(x='Duration',y='Himachal Pradesh',data = df)
plt.ylabel('Year')
plt.xlabel('Himachal Pradesh')
plt.show()
plt.scatter(x='Duration',y='Jammu & Kashmir',data = df)
plt.ylabel('Year')
plt.xlabel('Jammu & Kashmir')
plt.show()

plt.scatter(x='Duration',y='Jharkhand',data = df)
plt.ylabel('Year')
plt.xlabel('Jharkhand')
plt.show()

plt.scatter(x='Duration',y='Karnataka',data = df)
plt.ylabel('Year')
plt.xlabel('Karnataka')
plt.show()

plt.scatter(x='Duration',y='Kerala',data = df)
plt.ylabel('Year')
plt.xlabel('Kerala')
plt.show()

plt.scatter(x='Duration',y='Madhya Pradesh',data = df)
plt.ylabel('Year')
plt.xlabel('Madhya Pradesh')
plt.show()

plt.scatter(x='Duration',y='Maharashtra',data = df)
plt.ylabel('Year')
plt.xlabel('Maharashtra')
plt.show()

plt.scatter(x='Duration',y='Manipur',data = df)
plt.ylabel('Year')
plt.xlabel('Manipur')
plt.show()

plt.scatter(x='Duration',y='Meghalaya',data = df)
plt.ylabel('Year')
plt.xlabel('Meghalaya')
plt.show()

plt.scatter(x='Duration',y='Mizoram',data = df)
plt.ylabel('Year')
plt.xlabel('Mizoram')
plt.show()

plt.scatter(x='Duration',y='Nagaland',data = df)
plt.ylabel('Year')
plt.xlabel('Nagaland')
plt.show()

plt.scatter(x='Duration',y='Odisha',data = df)
plt.ylabel('Year')
plt.xlabel('Odisha')
plt.show()

plt.scatter(x='Duration',y='Punjab',data = df)
plt.ylabel('Year')
plt.xlabel('Punjab')
plt.show()

plt.scatter(x='Duration',y='Rajasthan',data = df)
plt.ylabel('Year')
plt.xlabel('Rajasthan')
plt.show()

plt.scatter(x='Duration',y='Sikkim',data = df)
plt.ylabel('Year')
plt.xlabel('Sikkim')
plt.show()

plt.scatter(x='Duration',y='Tamil Nadu',data = df)
plt.ylabel('Year')
plt.xlabel('Tamil Nadu')
plt.show()

plt.scatter(x='Duration',y='Telangana',data = df)
plt.ylabel('Year')
plt.xlabel('Telangana')
plt.show()

plt.scatter(x='Duration',y='Tripura',data = df)
plt.ylabel('Year')
plt.xlabel('Tripura')
plt.show()

plt.scatter(x='Duration',y='Uttar Pradesh',data = df)
plt.ylabel('Year')
plt.xlabel('Uttar Pradesh')
plt.show()

plt.scatter(x='Duration',y='Uttarakhand',data = df)
plt.ylabel('Year')
plt.xlabel('Uttarakhand')
plt.show()

plt.scatter(x='Duration',y='All_India GDP',data = df)
plt.ylabel('Year')
plt.xlabel('All_India GDP')
plt.show()

# %%
import numpy as np
##Duration.split('-')[0]
df = df[['Duration'].split(0)]
m,C = np.polyfit(df['Duration'],df['Andhra Pradesh'].astype(np.str),1)
plt.scatter(x='Duration',y='Andhra Pradesh',data = df)
##plt.ylabel('Year)')
##plt.xlabel('Andhra Pradesh')
plt.plot(df['Duration'],m*df['Duration']+C, '--r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-83d9b077ddad> in <module>
#       1 import numpy as np
#       2 ##Duration.split('-')[0]
# ----> 3 df = df[['Duration'].split(0)]
#       4 m,C = np.polyfit(df['Duration'],df['Andhra Pradesh'].astype(np.str),1)
#       5 plt.scatter(x='Duration',y='Andhra Pradesh',data = df)
#
# AttributeError: 'list' object has no attribute 'split'

# %%
import numpy as np
##Duration.split('-')[0]
df[['Duration'].split(0)]
m,C = np.polyfit(df['Duration'],df['Andhra Pradesh'].astype(np.str),1)
plt.scatter(x='Duration',y='Andhra Pradesh',data = df)
##plt.ylabel('Year)')
##plt.xlabel('Andhra Pradesh')
plt.plot(df['Duration'],m*df['Duration']+C, '--r')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-35-953a5eea9afe> in <module>
#       1 import numpy as np
#       2 ##Duration.split('-')[0]
# ----> 3 df[['Duration'].split(0)]
#       4 m,C = np.polyfit(df['Duration'],df['Andhra Pradesh'].astype(np.str),1)
#       5 plt.scatter(x='Duration',y='Andhra Pradesh',data = df)
#
# AttributeError: 'list' object has no attribute 'split'

# %%
import numpy as np
##Duration.split('-')[0]
m,C = np.polyfit(df['Duration'],range(len(df['Andhra Pradesh'])),1)
plt.scatter(x='Duration',y='Andhra Pradesh',data = df)
##plt.ylabel('Year)')
##plt.xlabel('Andhra Pradesh')
plt.plot(df['Duration'],m*df['Duration']+C, '--r')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-a77cc2f90516> in <module>
#       1 import numpy as np
#       2 ##Duration.split('-')[0]
# ----> 3 m,C = np.polyfit(df['Duration'],range(len(df['Andhra Pradesh'])),1)
#       4 plt.scatter(x='Duration',y='Andhra Pradesh',data = df)
#       5 ##plt.ylabel('Year)')
#
# C:\Dibyalok\lib\site-packages\numpy\lib\polynomial.py in polyfit(x, y, deg, rcond, full, w, cov)
#     587     """
#     588     order = int(deg) + 1
# --> 589     x = NX.asarray(x) + 0.0
#     590     y = NX.asarray(y) + 0.0
#     591
#
# TypeError: can only concatenate str (not "float") to str

# %%
import pandas as pd
import glob
path =r'C:\Dibyalok\1A'
all_files = glob.glob(path+'/*.csv')
df = pd.read_csv(all_files[0])

df.columns = [c.replace(' ', '_') for c in df.columns]

df_GSDP_2015_16 = df.loc[df.Duration == '2015-16']

df_GSDP_2015_16
# Out:
#                    Items__Description Duration  Andhra_Pradesh  \
# 4  GSDP - CURRENT PRICES (` in Crore)  2015-16       609934.00
# 9       (% Growth over previous year)  2015-16           15.85
#
#    Arunachal_Pradesh      Assam      Bihar  Chhattisgarh       Goa    Gujarat  \
# 4           18784.00  224234.00  413503.00     260776.00  45002.00  994316.00
# 9              12.07      13.19      10.59         10.98     10.75      11.09
#
#      Haryana  ...  Telangana  Tripura  Uttar_Pradesh  Uttarakhand  \
# 4  485184.00  ...  575631.00      NaN     1153795.00    184091.00
# 9      10.91  ...      12.61      NaN          10.58        13.65
#
#    West_Bengal1  Andaman_&_Nicobar_Islands  Chandigarh      Delhi  Puducherry  \
# 4           NaN                        NaN    30304.00  551963.00    26533.00
# 9           NaN                        NaN        8.84      12.09       10.15
#
#    All_India_GDP
# 4    13675331.00
# 9           9.99
#
# [2 rows x 36 columns]

# %%
GDP_grw_rate_states = df_GSDP_2015_16.loc[(df.Items__Description != "(% Growth over previous year)")&(df.Duration == '2015-16')]


GDP_grw_rate_states = GDP_grw_rate_states.T
GDP_grw_rate_states.columns=GDP_grw_rate_states.iloc[0]
GDP_grw_rate_states = GDP_grw_rate_states[2:-4]
GDP_grw_rate_NotNull = GDP_grw_rate_states.dropna()


GDP_grw_rate_NotNull
# Out:
# Items__Description GSDP - CURRENT PRICES (` in Crore)
# Andhra_Pradesh                                 609934
# Arunachal_Pradesh                               18784
# Assam                                          224234
# Bihar                                          413503
# Chhattisgarh                                   260776
# Goa                                             45002
# Gujarat                                        994316
# Haryana                                        485184
# Jammu_&_Kashmir                                118387
# Jharkhand                                      241955
# Karnataka                                 1.02707e+06
# Kerala                                         588337
# Madhya_Pradesh                                 543975
# Meghalaya                                       26745
# Odisha                                         341887
# Sikkim                                          16637
# ...

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(20,10))

GDP_grw_rate_NotNull.plot(kind='bar')

plt.ylabel('Total GDP 2015-2016 ');plt.xlabel('All States Of India')

plt.title('GDP Growth Rates Of States in 2015-2016')

plt.show()

# %%
########*****Part I-B*****#######

import glob, os
import pandas as pd

dir_path =r'C:\Dibyalok\1B'

file_paths = glob.glob(os.path.join(dir_path+'/*.csv'))
df = pd.read_csv(file_paths[0])
df.head(100)
# Out:
#     S.No.                                               Item   2011-12  \
# 0       1                  Agriculture, forestry and fishing   9400805
# 1     1.1                                              Crops   5204052
# 2     1.2                                          Livestock   2758776
# 3     1.3                               Forestry and logging    250314
# 4     1.4                            Fishing and aquaculture   1187663
# 5       2                               Mining and quarrying   1416194
# 6   Total                                            Primary  10816999
# 7       3                                      Manufacturing   5070622
# 8       4  Electricity, gas, water supply & other utility...   1076517
# 9       5                                       Construction   3702645
# 10  Total                                          Secondary   9849784
# 11      6              Trade, repair, hotels and restaurants   2673600
# ...

# %%
import glob, os
import pandas as pd

dir_path =r'C:\Dibyalok\1B'


file_paths = glob.glob(os.path.join(dir_path+'/*.csv'))


req_columns = ['S.No.','Item','2014-15'] 

union_territories = ["Delhi", 'Chandigarh', 'Puducherry', 'Andaman & Nicobar Islands', 'Lakshadweep', 'Daman & Diu, Dadra & Nagar Haveli']


df_PerCapita_allstates = pd.concat([pd.read_csv(i, encoding = 'ISO8859', usecols=req_columns).assign(State = i.split('+')[-1].replace('_',' ')) 
               for i in file_paths if i.split('+')[-1].replace('_',' ')not in union_territories])

df_PerCapita_allstates['State'] = df_PerCapita_allstates['State'].str.split('.').str[-2]

df_PerCapita_allstates
# Out:
#    S.No.                               Item      2014-15           State
# 0      1  Agriculture, forestry and fishing   14819416.0  Andhra Pradesh
# 1    1.1                              Crops    7893514.0  Andhra Pradesh
# 2    1.2                          Livestock    4309078.0  Andhra Pradesh
# 3    1.3               Forestry and logging     346160.0  Andhra Pradesh
# 4    1.4            Fishing and aquaculture    2270664.0  Andhra Pradesh
# ..   ...                                ...          ...             ...
# 28    13                  Taxes on Products   10107396.0   Uttar Pradesh
# 29    14              Subsidies on products    3287219.0   Uttar Pradesh
# 30    15       Gross State Domestic Product  104337115.0   Uttar Pradesh
# 31    16                   Population ('00)    2109940.0   Uttar Pradesh
# 32    17              Per Capita GSDP (Rs.)      49450.0   Uttar Pradesh
#
# [990 rows x 4 columns]

# %%
plt.figure(figsize=(12,10))

df_PerCapita_allstates.loc[(df_all_states.Item == "Per Capita GSDP (Rs.)")].iloc[:,2:].sort_values(by = '2014-15').set_index('State').iloc[:,-1].plot(kind='bar')

plt.ylabel('Per Capita GSDP')

plt.xlabel('All States Of India')

plt.show()

# %%
df_PerCapita_allstates.loc[(df_all_states.State == "Goa")&(df_all_states.Item == "Per Capita GSDP (Rs.)")].iloc[:,-2].T[32] / df_PerCapita_allstates.loc[(df_all_states.State == "Bihar")&(df_PerCapita_allstates.Item == "Per Capita GSDP (Rs.)")].iloc[:,-2].T[32]
# Out:
# 8.004741709371503

# %%
df_total_GDP = df_PerCapita_allstates.loc[(df_PerCapita_allstates.Item == "Gross State Domestic Product")][['2014-15','State']].rename(columns={'2014-15':'GSDP'})

df_total_GDP.head(40)
# Out:
#            GSDP              State
# 30   52646842.0     Andhra Pradesh
# 30    1676119.0  Arunachal Pradesh
# 30   19809800.0              Assam
# 30   37391988.0              Bihar
# 30    2784426.0         Chandigarh
# 30   23498180.0       Chhattisgarh
# 30   49242422.0              Delhi
# 30    4063307.0                Goa
# 30   89502727.0            Gujarat
# 30   43746207.0            Haryana
# 30   10436879.0   Himachal Pradesh
# 30   21710718.0          Jharkhand
# 30   92178806.0          Karnataka
# 30   52600230.0             Kerala
# 30   48198169.0     Madhya Pradesh
# 30  179212165.0        Maharashtra
# 30    1804276.0            Manipur
# 30    2440807.0          Meghalaya
# 30    1155933.0            Mizoram
# 30    1841424.0           Nagaland
# 30   32197092.0             Odisha
# 30    2408857.0         Puducherry
# 30   36801089.0             Punjab
# 30   61219447.0          Rajasthan
# 30    1520933.0             Sikkim
# 30  109256373.0         Tamil Nadu
# ...

# %%
df_primary_sector = df_all_states.loc[(df_all_states.Item == "Primary")][['2014-15','State']].rename(columns={'2014-15':'Primary_GSVA'}) # same as above

df_primary_sector = pd.merge(df_prim_sec_ter, df_all_states.loc[(df_all_states.Item == "Secondary")][['2014-15','State']], how = 'inner', on = 'State').rename(columns={'2014-15':'Secondary_GSVA'})

df_primary_sector= pd.merge(df_prim_sec_ter, df_all_states.loc[(df_all_states.Item == "Tertiary")][['2014-15','State']], how = 'inner', on = 'State').rename(columns={'2014-15':'Tertiary_GSVA'})

df_primary_sector.head()
# Out:
#    Primary_GSVA              State  Secondary_GSVA  Tertiary_GSVA  \
# 0    16303716.0     Andhra Pradesh      10488884.0     22032942.0
# 1      716959.0  Arunachal Pradesh        287489.0       631844.0
# 2     5326697.0              Assam       4033091.0      9307109.0
# 3     8019997.0              Bihar       5984896.0     22179969.0
# 4       16412.0         Chandigarh        312693.0      2426008.0
#
#    Tertiary_GSVA
# 0     22032942.0
# 1       631844.0
# 2      9307109.0
# 3     22179969.0
# 4      2426008.0

# %%
df_total_GDP_pri_sec_ter = pd.merge(df_prim_sec_ter, df_total_GDP, how = 'inner', on = 'State')

df_total_GDP_pri_sec_ter.head()
# Out:
#    Primary_GSVA              State  Secondary_GSVA  Tertiary_GSVA        GSDP
# 0    16303716.0     Andhra Pradesh      10488884.0     22032942.0  52646842.0
# 1      716959.0  Arunachal Pradesh        287489.0       631844.0   1676119.0
# 2     5326697.0              Assam       4033091.0      9307109.0  19809800.0
# 3     8019997.0              Bihar       5984896.0     22179969.0  37391988.0
# 4       16412.0         Chandigarh        312693.0      2426008.0   2784426.0

# %%
df_total_GDP_pri_sec_ter['%_Primary_Contribution'] = (df_total_GDP_pri_sec_ter['Primary_GSVA']/df_total_GDP_pri_sec_ter['GSDP'])*100

df_total_GDP_pri_sec_ter['%_Secondary_Contribution'] = (df_total_GDP_pri_sec_ter['Secondary_GSVA']/df_total_GDP_pri_sec_ter['GSDP'])*100

df_total_GDP_pri_sec_ter['%_Tertiary_Contribution'] = (df_total_GDP_pri_sec_ter['Tertiary_GSVA']/df_total_GDP_pri_sec_ter['GSDP'])*100

df_total_GDP_pri_sec_ter['Total_pri_sec_tri_%'] = df_total_GDP_pri_sec_ter['%_Primary_Contribution']+df_total_GDP_pri_sec_ter['%_Secondary_Contribution']+df_total_GDP_pri_sec_ter['%_Tertiary_Contribution']

df_total_GDP_pri_sec_ter = df_total_GDP_pri_sec_ter.sort_values(by='Total_pri_sec_tri_%',ascending=False)

df_total_GDP_pri_sec_ter.head()
# Out:
#     Primary_GSVA       State  Secondary_GSVA  Tertiary_GSVA       GSDP  \
# 4        16412.0  Chandigarh        312693.0      2426008.0  2784426.0
# 19      616178.0    Nagaland        212361.0       992956.0  1841424.0
# 16      383140.0     Manipur        220173.0      1177334.0  1804276.0
# 27      942216.0     Tripura        484393.0      1484709.0  2966662.0
# 18      225598.0     Mizoram        270072.0       637619.0  1155933.0
#
#     %_Primary_Contribution  %_Secondary_Contribution  %_Tertiary_Contribution  \
# 4                 0.589421                 11.230070                87.127760
# 19               33.462038                 11.532434                53.923268
# 16               21.235110                 12.202845                65.252434
# 27               31.760140                 16.327880                50.046450
# 18               19.516529                 23.363984                55.160550
#
#     Total_pri_sec_tri_%
# 4             98.947252
# ...

# %%
import numpy as np

Primary = df_total_GDP_pri_sec_ter['%_Primary_Contribution']

Secondary = df_total_GDP_pri_sec_ter['%_Secondary_Contribution']

Tertiary = df_total_GDP_pri_sec_ter['%_Tertiary_Contribution']

States = df_total_GDP_pri_sec_ter['State'] 

plt.figure(figsize=(14,6))

p1 = plt.bar(States, Primary)

p2 = plt.bar(States, Secondary, bottom=Primary)

p3 = plt.bar(States, Tertiary, bottom=np.array(Primary)+np.array(Secondary))

plt.ylabel('Total GSDP Percentage (%)')

plt.title('Percentage Contribution of Each sector to GSDP')

plt.xticks(States,rotation=90)

plt.yticks(np.arange(0, 110, 10)); plt.xlabel('All States Of India')

plt.legend((p1[0], p2[0], p3[0]), ('Primary', 'Secondary', 'Tertiary'))

plt.show()

# %%
#######*******Part-II: GDP and Education Drop-out Rates*****########
import pandas as pd
import glob
path =r'C:\Dibyalok\GDP_EducationDropoutRates'
all_files = glob.glob(path+'/*.csv')
df_EDU = pd.read_csv(all_files[0])

# %%
df_EDU = pd.read_csv(all_files[0])
df_EDU.head(50)
# Out:
#       Sl. No. Level of Education - State  Primary - 2012-2013  \
# 0           1              A & N Islands                 0.68
# 1           2             Andhra Pradesh                 3.18
# 2           3          Arunachal Pradesh                15.16
# 3           4                      Assam                 6.24
# 4           5                      Bihar                  NaN
# 5           6                 Chandigarh                  NaN
# 6           7                Chhatisgarh                 4.14
# 7           8       Dadra & Nagar Haveli                  NaN
# 8           9                Daman & Diu                  NaN
# 9          10                      Delhi                  NaN
# 10         11                        Goa                  NaN
# 11         12                    Gujarat                 0.74
# 12         13                    Haryana                 1.29
# 13         14           Himachal Pradesh                 0.45
# ...

# %%
df_EDU = df_EDU.rename(columns = {'Level of Education - State':'State'})
df_EDU
# Out:
#       Sl. No.                 State  Primary - 2012-2013  Primary - 2014-2015  \
# 0           1         A & N Islands                 0.68                 1.21
# 1           2        Andhra Pradesh                 3.18                 4.35
# 2           3     Arunachal Pradesh                15.16                10.89
# 3           4                 Assam                 6.24                 7.44
# 4           5                 Bihar                  NaN                 2.09
# 5           6            Chandigarh                  NaN                  NaN
# 6           7           Chhatisgarh                 4.14                 1.42
# 7           8  Dadra & Nagar Haveli                  NaN                 1.57
# 8           9           Daman & Diu                  NaN                 0.85
# 9          10                 Delhi                  NaN                  NaN
# 10         11                   Goa                  NaN                 0.20
# ...

# %%
df_EDU = df_EDU[['State','Primary - 2014-2015.1','Upper Primary - 2014-2015','Secondary - 2014-2015']]

df_EDU.head(50)
# Out:
#                    State  Primary - 2014-2015.1  Upper Primary - 2014-2015  \
# 0          A & N Islands                   0.51                       1.69
# 1         Andhra Pradesh                   6.72                       5.20
# 2      Arunachal Pradesh                  10.82                       6.71
# 3                  Assam                  15.36                      10.51
# 4                  Bihar                    NaN                       4.08
# 5             Chandigarh                    NaN                       0.44
# 6            Chhatisgarh                   2.91                       5.85
# 7   Dadra & Nagar Haveli                   1.47                       4.02
# 8            Daman & Diu                   1.11                       3.11
# 9                  Delhi                    NaN                       0.76
# 10                   Goa                   0.73                       0.07
# ...

# %%
df_EDU = df_EDU.dropna(how='any')

df_EDU
# Out:
#    Sl. No.              State  Primary - 2012-2013  Primary - 2014-2015  \
# 0        1      A & N Islands                 0.68                 1.21
# 2        3  Arunachal Pradesh                15.16                10.89
# 11      12            Gujarat                 0.74                 0.76
# 13      14   Himachal Pradesh                 0.45                 0.46
# 14      15  Jammu and Kashmir                 6.30                 5.46
# 20      21        Maharashtra                 0.97                 0.55
# 24      25           Nagaland                 7.07                19.41
# 26      27         Puducherry                 0.34                 0.66
# 27      28             Punjab                 1.99                 1.29
# 29      30             Sikkim                 3.60                 4.57
# 32      33            Tripura                 2.22                 3.58
# 35      36        West Bengal                 6.30                 2.91
#
# ...

# %%
df_EDU = df_EDU.replace(['Chhatisgarh','Uttrakhand'],['Chhattisgarh','Uttarakhand'])

df_EDU
# Out:
#                    State  Primary - 2014-2015.1  Upper Primary - 2014-2015  \
# 0          A & N Islands                   0.51                       1.69
# 1         Andhra Pradesh                   6.72                       5.20
# 2      Arunachal Pradesh                  10.82                       6.71
# 3                  Assam                  15.36                      10.51
# 6           Chhattisgarh                   2.91                       5.85
# 7   Dadra & Nagar Haveli                   1.47                       4.02
# 8            Daman & Diu                   1.11                       3.11
# 10                   Goa                   0.73                       0.07
# 11               Gujarat                   0.89                       6.41
# 12               Haryana                   5.61                       5.81
# 13      Himachal Pradesh                   0.64                       0.87
# ...

# %%
df_PerCapita_allstates

df_dropout_EDUpercap = pd.merge(df_PerCapita_allstates[df_PerCapita_allstates.Item=='Per Capita GSDP (Rs.)'], df_EDU, how = 'inner', on = 'State')

df_dropout_EDUpercap
# Out:
#   S.No.                   Item   2014-15              State Sl. No.  \
# 0    17  Per Capita GSDP (Rs.)  112718.0  Arunachal Pradesh       3
# 1    17  Per Capita GSDP (Rs.)  141263.0            Gujarat      12
# 2    17  Per Capita GSDP (Rs.)  147330.0   Himachal Pradesh      14
# 3    17  Per Capita GSDP (Rs.)  152853.0        Maharashtra      21
# 4    17  Per Capita GSDP (Rs.)   89607.0           Nagaland      25
# 5    17  Per Capita GSDP (Rs.)  175701.0         Puducherry      27
# 6    17  Per Capita GSDP (Rs.)  126606.0             Punjab      28
# 7    17  Per Capita GSDP (Rs.)  240274.0             Sikkim      30
# 8    17  Per Capita GSDP (Rs.)   77358.0            Tripura      33
#
#    Primary - 2012-2013  Primary - 2014-2015  Primary - 2014-2015.1  \
# 0                15.16                10.89                  10.82
# 1                 0.74                 0.76                   0.89
# 2                 0.45                 0.46                   0.64
# ...

# %%
df_dropout_EDUpercap['Total_dropout_in_2014-15'] = df_dropout_EDUpercap.iloc[:,-3:].sum(axis = 1)

df_dropout_EDUpercap
# Out:
#   S.No.                   Item   2014-15              State Sl. No.  \
# 0    17  Per Capita GSDP (Rs.)  112718.0  Arunachal Pradesh       3
# 1    17  Per Capita GSDP (Rs.)  141263.0            Gujarat      12
# 2    17  Per Capita GSDP (Rs.)  147330.0   Himachal Pradesh      14
# 3    17  Per Capita GSDP (Rs.)  152853.0        Maharashtra      21
# 4    17  Per Capita GSDP (Rs.)   89607.0           Nagaland      25
# 5    17  Per Capita GSDP (Rs.)  175701.0         Puducherry      27
# 6    17  Per Capita GSDP (Rs.)  126606.0             Punjab      28
# 7    17  Per Capita GSDP (Rs.)  240274.0             Sikkim      30
# 8    17  Per Capita GSDP (Rs.)   77358.0            Tripura      33
#
#    Primary - 2012-2013  Primary - 2014-2015  Primary - 2014-2015.1  \
# 0                15.16                10.89                  10.82
# 1                 0.74                 0.76                   0.89
# 2                 0.45                 0.46                   0.64
# ...

# %%
x = df_dropout_EDUpercap['2014-15'].values

y1 = df_dropout_EDUpercap['Primary - 2014-2015.1'].values

y2 = df_dropout_EDUpercap['Upper Primary - 2014-2015'].values

y3 = df_dropout_EDUpercap['Secondary - 2014-2015'].values

y4 = df_dropout_EDUpercap['Total_dropout_in_2014-15'].values

plt.figure(figsize=(15,10))

plt.subplot(221)

plt.title('GSDP vs primary Dropout Rate in 2014-2015')

plt.xlabel('GSDP in Crores')

plt.ylabel('Dropout in Percentage')

plt.scatter(x,y1)

plt.subplot(222)

plt.title('GSDP vs Upper-Primary Dropout Rate in 2014-2015')

plt.xlabel('GSDP in Crores')

plt.ylabel('Dropout in Percentage')

plt.scatter(x,y2)

plt.subplot(223)

plt.title('GSDP vs Secondary Dropout Rate in 2014-2015')

plt.xlabel('GSDP in Crores')

plt.ylabel('Dropout in Percentage')

plt.scatter(x,y3)

plt.subplot(224)

plt.title('GSDP vs Total Dropout Rate in 2014-2015')

plt.xlabel('GSDP in Crores')

plt.ylabel('Dropout in Percentage')

plt.scatter(x,y4)

plt.show()

# %%
###************Finding the Co-Relation between Dropout Rate and % Contribution from each sector*********###

from numpy import *
import matplotlib.pyplot as plt

def plot_best_fitline(intercept, slope):
    axes = plt.gca()
    x_vals = array(axes.get_xlim())
    y_vals = intercept + slope * x_vals
    plt.plot(x_vals, y_vals, 'r-')


from sklearn.linear_model import LinearRegression
    
def RegressionAnalysis(X,Y):   
    regr = LinearRegression()
    regr.fit(X,Y)
    return regr



plt.figure(figsize=(14,12))

plt.subplot(221)

plt.scatter(x,y1)

regr = RegressionAnalysis(x.reshape(-1,1) ,y1.reshape(-1,1))

plot_best_fit((regr.intercept_)[0],(regr.coef_)[0][0])

plt.title('GSDP vs Dropout Rate in Primary During 2014-2015 (Fig 1)')

plt.xlabel('GSDP in Crores (Rs.)')

plt.ylabel('Dropout rate in Percentage')

plt.subplot(222)

plt.scatter(x,y2)

regr = RegressionAnalysis(x.reshape(-1,1) ,y2.reshape(-1,1))

plot_best_fitline((regr.intercept_)[0],(regr.coef_)[0][0])

plt.title('GSDP vs Dropout Rate in Upper-Primary During 2014-2015 (Fig 2)')

plt.xlabel('GSDP in Crores (Rs.)')

plt.ylabel('Dropout rate in Percentage')

plt.subplot(223)

plt.scatter(x,y3)

regr = RegressionAnalysis(x.reshape(-1,1) ,y3.reshape(-1,1))

plot_best_fitline((regr.intercept_)[0],(regr.coef_)[0][0])

plt.title('GSDP vs Dropout Rate in Secondary During 2014-2015 (Fig 3)')

plt.xlabel('GSDP in Crores (Rs.)')

plt.ylabel('Dropout rate in Percentage')

plt.subplot(224)

plt.scatter(x,y4)

regr = RegressionAnalysis(x.reshape(-1,1) ,y4.reshape(-1,1))

plot_best_fitline((regr.intercept_)[0],(regr.coef_)[0][0])

plt.title('GSDP vs Total Dropout Rate During 2014-2015 (Fig 4)')

plt.xlabel('GSDP in Crores (Rs.)')

plt.ylabel('Dropout rate in Percentage')

plt.show()
